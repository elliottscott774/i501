# %% [markdown]
# # Intro to Natural Language Processing (NLP)
#
# The Natural Language Processing (NLP) field is incredibly vast, and it has applications in virtually every aspect of data science. In this notebook, we will walk through a **very brief** survey of NLP, and provide some instruction on a couple handy tools along the way.
#
# NLP tools span a wide range of implementations, and it is not uncommon for NLP packages to have conflicts with other Python libraries. So, to keep everything compatible in one place, it is recommended that you create a new pip environment for NLP projects. To set up an NLP pip environment for this lab, follow the steps in the "Pip Environment" section of the [Python Environment Setup page in Canvas](https://iu.instructure.com/courses/2181786/pages/week-1-%7C-python-environment-setup?module_item_id=30340853), and **use the *environment.yml* file provided in this folder.** This should install the packages you'll need for this lab.
#
# Next, **[download a spaCy NLP model](https://spacy.io/models)** based on your preferences (in the NLP environment) so you can use the spaCy library installed in the environment.
#
# *Optionally, if you prefer to use a different environment, install the following packages separately using pip: [Scikit-Learn](https://scikit-learn.org/stable/install.html#installing-the-latest-release), [spaCy](https://spacy.io/usage), [ScatterText](https://github.com/JasonKessler/scattertext#installation), [CorEx](https://ryanjgallagher.github.io/code/corex/example), and [vaderSentiment](https://github.com/cjhutto/vaderSentiment#installation).*

# %% [markdown]
# ## Preprocessing
#
# To illustrate preprocessing text data, we'll use the [spaCy](https://spacy.io/) package.
#
# *spaCy is capable of **much** more than just preprocessing, but we are only concerned with this feature for this lab. More complicated implementations of the package will come back in a later lesson, or they're more appropriate for a more advanced course.*

# %%
import pandas as pd
import spacy
from spacy import displacy
print(spacy.__version__)
# Out:
# 3.7.4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# ### Tokenizing
#
# The very first part of dealing with text data is to collect each **term** or unitary element of text (e.g., words, punctuation, etc.) in the form of "tokens".

# %%
# depends on your choice of spaCy model
nlp = spacy.load('en_core_web_sm')

# %%
intro = '''The Natural Language Processing (NLP) field is incredibly vast,
and it has applications in virtually every aspect of data science.
In this notebook, we will walk through a **very brief** survey of NLP,
and provide some instruction on a couple handy tools along the way.
'''

doc = nlp(intro)

# %%
print([t.text for t in doc])
# Out:
# ['The', 'Natural', 'Language', 'Processing', '(', 'NLP', ')', 'field', 'is', 'incredibly', 'vast', ',', '\n', 'and', 'it', 'has', 'applications', 'in', 'virtually', 'every', 'aspect', 'of', 'data', 'science', '.', '\n', 'In', 'this', 'notebook', ',', 'we', 'will', 'walk', 'through', 'a', '*', '*', 'very', 'brief', '*', '*', 'survey', 'of', 'NLP', ',', '\n', 'and', 'provide', 'some', 'instruction', 'on', 'a', 'couple', 'handy', 'tools', 'along', 'the', 'way', '.', '\n']

# %%
for i, sentence in enumerate(doc.sents):
    print(f"sentence {i+1}\n\n", sentence)
# Out:
# sentence 1
#
#  The Natural Language Processing (NLP) field is incredibly vast,
# and it has applications in virtually every aspect of data science.
#
# sentence 2
#
#  In this notebook, we will walk through a **very brief** survey of NLP,
# and provide some instruction on a couple handy tools along the way.

# %%
df_intro = []

for token in doc:
    df_intro.append([
        token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
        token.shape_, token.is_alpha, token.is_stop
    ])

# %%
df_intro = pd.DataFrame(columns=["text", "lemma_", "pos_", "tag_", "dep_", "shape_", "is_alpha", "is_stop"],
                        data=df_intro)

# %%
df_intro.sample(5)
# Out:
#      text lemma_   pos_ tag_   dep_ shape_  is_alpha  is_stop
# 34      a      a    DET   DT    det      x      True     True
# 21     of     of    ADP   IN   prep     xx      True     True
# 54  tools   tool   NOUN  NNS   pobj   xxxx      True    False
# 58      .      .  PUNCT    .  punct      .     False    False
# 45     \n     \n  SPACE  _SP    dep     \n     False    False

# %% [markdown]
# What is a **stop word**?

# %%
df_intro[df_intro['is_stop']].sample(10)
# Out:
#      text lemma_   pos_ tag_      dep_ shape_  is_alpha  is_stop
# 13    and    and  CCONJ   CC        cc    xxx      True     True
# 0     The    the    DET   DT       det    Xxx      True     True
# 55  along  along    ADP   IN      prep   xxxx      True     True
# 14     it     it   PRON  PRP     nsubj     xx      True     True
# 37   very   very    ADV   RB    advmod   xxxx      True     True
# 31   will   will    AUX   MD       aux   xxxx      True     True
# 51      a      a    DET   DT  quantmod      x      True     True
# 34      a      a    DET   DT       det      x      True     True
# 17     in     in    ADP   IN      prep     xx      True     True
# 27   this   this    DET   DT       det   xxxx      True     True

# %% [markdown]
# **Sentence Dependencies**

# %% [markdown]
# We can visualize some of these (like the sentence dependencies) using [displacy](https://spacy.io/usage/visualizers).

# %%
doc = nlp('We can visualize these using displacy.')

# %%
displacy.render(doc, style='dep', options={'distance': 80})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a8b1c69221f44228a5f30a5353609f6d-0" class="displacy" width="530" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">visualize</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">these</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">displacy.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a8b1c69221f44228a5f30a5353609f6d-0-0" stroke-width="2px" d="M70,122.0 C70,42.0 205.0,42.0 205.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a8b1c69221f44228a5f30a5353609f6d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a8b1c69221f44228a5f30a5353609f6d-0-1" stroke-width="2px" d="M150,122.0 C150,82.0 200.0,82.0 200.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a8b1c69221f44228a5f30a5353609f6d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150,124.0 L142,112.0 158,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a8b1c69221f44228a5f30a5353609f6d-0-2" stroke-width="2px" d="M310,122.0 C310,42.0 445.0,42.0 445.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a8b1c69221f44228a5f30a5353609f6d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,124.0 L302,112.0 318,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a8b1c69221f44228a5f30a5353609f6d-0-3" stroke-width="2px" d="M390,122.0 C390,82.0 440.0,82.0 440.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a8b1c69221f44228a5f30a5353609f6d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M390,124.0 L382,112.0 398,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a8b1c69221f44228a5f30a5353609f6d-0-4" stroke-width="2px" d="M230,122.0 C230,2.0 450.0,2.0 450.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a8b1c69221f44228a5f30a5353609f6d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,124.0 L458.0,112.0 442.0,112.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ### Named Entity Recognition
#
# Some words are **Named Entities**: locations like "Alaska", dates like "January 1st", companies like "Google", etc. spaCy can tag these using [Named Entity Recognition](https://spacy.io/usage/linguistic-features#named-entities).

# %%
doc = nlp('... locations like "Alaska", dates like "January 1st", companies like "Google", etc.')

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">... locations like &quot;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alaska
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# &quot;, dates like &quot;
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 1st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# &quot;, companies like &quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# &quot;, etc.</div></span>

# %% [markdown]
# ### Multiple Documents
#
# *NLP Terms: A **document** is a collection of tokens, and a **corpus** is a collection of documents.*
#
# When spaCy processes text, it runs it through a [pipeline](https://spacy.io/usage/processing-pipelines) of different models to store token attributes for each token. This is how we get the functionality above. Though, when we are tokenizing multiple documents, we might not need all of these elements. We might just need enough to filter our text based on the analysis done.
#
# For example, suppose we've determined that we want to the remove the following tokens from a dataset of [coffee reviews](https://www.kaggle.com/datasets/schmoyote/coffee-reviews-dataset/) (descriptions):
#
# - stop words (except the lemma "not", to maintain the idea of object negation)
# - punctuation
# - numbers
#
# In this case, we don't need NER, Dependency Labels, or Document Labels. Removing these processes from the spaCy pipeline will save us some time.

# %%
df_coffee = pd.read_csv('./data/coffee_analysis.csv')

# %%
print(df_coffee['desc_1'].sample().iloc[0])
# Out:
# Crisp, delicate, richly sweet. Yellow plum, cocoa powder, narcissus, sandalwood, brown sugar in aroma and cup. Sweet-toned structure with lively acidity; full, satiny mouthfeel. Cocoa-toned plum and a hint of narcissus enliven the quiet finish.

# %%
# nlp.pipe returns a generator
docs = list(nlp.pipe(df_coffee['desc_1'], disable=['ner', 'parser', 'textcat']))

# save the spaCy objects into the DataFrame
df_coffee['spacy_doc'] = docs

# %%
def tokenizer(docs, join_tokens=False):
    '''
    Tokenize an iterable of spaCy `docs`.

    join_tokens : bool
        Whether we want to return a list of strings or
        a list of lists. If True, join with space (" ").
    '''
    docs_clean = []

    for doc in docs:
        # collect only filtered words from each document
        tokens = [w.lemma_.lower() for w in doc if
                  (not w.is_stop
                   and not w.is_punct
                   and not w.like_num) \
                  or (w.lemma_ == 'not')]

        if join_tokens:
            docs_clean.append(' '.join(tokens))
        else:
            docs_clean.append(tokens)

    return docs_clean

# %%
df_coffee['docs_clean'] = tokenizer(docs)

# %%
df_coffee[['desc_1', 'spacy_doc', 'docs_clean']].head()
# Out:
#                                               desc_1  \
# 0  Evaluated as espresso. Sweet-toned, deeply ric...
# 1  Evaluated as espresso. Sweetly tart, floral-to...
# 2  Crisply sweet, cocoa-toned. Lemon blossom, roa...
# 3  Delicate, sweetly spice-toned. Pink peppercorn...
# 4  Deeply sweet, subtly pungent. Honey, pear, tan...
#
#                                            spacy_doc  \
# 0  (Evaluated, as, espresso, ., Sweet, -, toned, ...
# 1  (Evaluated, as, espresso, ., Sweetly, tart, ,,...
# 2  (Crisply, sweet, ,, cocoa, -, toned, ., Lemon,...
# 3  (Delicate, ,, sweetly, spice, -, toned, ., Pin...
# 4  (Deeply, sweet, ,, subtly, pungent, ., Honey, ...
#
#                                           docs_clean
# 0  [evaluate, espresso, sweet, tone, deeply, rich...
# 1  [evaluate, espresso, sweetly, tart, floral, to...
# 2  [crisply, sweet, cocoa, tone, lemon, blossom, ...
# 3  [delicate, sweetly, spice, tone, pink, pepperc...
# 4  [deeply, sweet, subtly, pungent, honey, pear, ...

# %%
print(df_coffee['desc_1'].iloc[0])
# Out:
# Evaluated as espresso. Sweet-toned, deeply rich, chocolaty. Vanilla paste, dark chocolate, narcissus, pink grapefruit zest, black cherry in aroma and cup. Plush, syrupy mouthfeel; resonant, flavor-saturated finish. In three parts milk, rich chocolate tones intensify, along with intimations of vanilla paste and black cherry in the short finish and floral-toned citrus zest in the long.

# %%
print(df_coffee['docs_clean'].iloc[0])
# Out:
# ['evaluate', 'espresso', 'sweet', 'tone', 'deeply', 'rich', 'chocolaty', 'vanilla', 'paste', 'dark', 'chocolate', 'narcissus', 'pink', 'grapefruit', 'zest', 'black', 'cherry', 'aroma', 'cup', 'plush', 'syrupy', 'mouthfeel', 'resonant', 'flavor', 'saturate', 'finish', 'part', 'milk', 'rich', 'chocolate', 'tone', 'intensify', 'intimation', 'vanilla', 'paste', 'black', 'cherry', 'short', 'finish', 'floral', 'tone', 'citrus', 'zest', 'long']

# %% [markdown]
# ## Vectorization
#
# Once we have our tokens selected and "cleaned", we need to convert the textual data into numerical data. **In other words, we need to convert each token (or document) into a *vector* representation.** There are many ways to represent textual information in the form of numerical data, but in this class we will cover Count Vectorization and Term-Frequency Inverse Document Frequency Vectorization; we'll call these **vectorizers**.

# %% [markdown]
# ### Brief Intro scikit-learn
#
# **[Scikit-Learn](https://scikit-learn.org/stable/index.html) is the industry standard data science toolkit**, and it's modules are used in almost every aspect of data science. Here, we are going to use its [feature extraction module](https://scikit-learn.org/stable/modules/feature_extraction.html), which is built for extracting numerical features from data such as text or images. We will be using it for vectorization of text data, and in these cases, the scikit-learn process is:
#
# 1. Preprocess some data (e.g., from text to tokens)
# 2. Define a model (e.g., a vectorizer)
# 3. "Fit" that model to the data using `.fit`
# 4. Transform the data based on the model's parameters using `.transform`
#     - We can also combine these last two steps with `.fit_transform`

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ### CountVectorizer
#
# CountVectorizer converts each document into a "Bag of Words". In other words, the document is encoded based on the words it contains, **regardless of the order**. And, each term can be represented based on the documents it is contained in.

# %%
corpus_raw = ['This coffee is really really tasty.',
              'Tea smells and tastes better than coffee.',
              "Best smelling coffee I have ever smelled!"]

# %%
cv = CountVectorizer(ngram_range=(1, 1),  # capture "pairs", or "n-tuples" of adjacent words
                     max_df=1.0,          # terms can't show up in ≥ `max_df` (or %) of docs
                     min_df=1,            # terms can't show up in ≤ `min_df` (or %) of docs
                     max_features=None,   # maximum number of terms/ngrams to include
                     binary=False)        # only log 1s and 0s for term presence

X = cv.fit_transform(corpus_raw)

df = pd.DataFrame(X.toarray(),
                  index=corpus_raw,
                  columns=cv.get_feature_names_out())

# %%
df
# Out:
#                                            and  best  better  coffee  ever  \
# This coffee is really really tasty.          0     0       0       1     0
# Tea smells and tastes better than coffee.    1     0       1       1     0
# Best smelling coffee I have ever smelled!    0     1       0       1     1
#
#                                            have  is  really  smelled  \
# This coffee is really really tasty.           0   1       2        0
# Tea smells and tastes better than coffee.     0   0       0        0
# Best smelling coffee I have ever smelled!     1   0       0        1
#
#                                            smelling  smells  tastes  tasty  \
# This coffee is really really tasty.               0       0       0      1
# Tea smells and tastes better than coffee.         0       1       1      0
# Best smelling coffee I have ever smelled!         1       0       0      0
#
#                                            tea  than  this
# This coffee is really really tasty.          0     0     1
# Tea smells and tastes better than coffee.    1     1     0
# Best smelling coffee I have ever smelled!    0     0     0

# %% [markdown]
# This is called a **document-term matrix**.
#
# - We could use `max_df` to remove the term "coffee" since it occurs in every document. This is one example of extracting *informative* features from text; i.e., the term "coffee" doesn't provide new information for each document.
# - Also, we can already see that some of these words give us more information than others. For example, "smelling" and "smells" mean roughly the same thing, and "had"/"have" aren't really necessary for understanding reviews.
#
# This is why we use the filtering in spaCy.

# %%
docs = nlp.pipe(corpus_raw)
corpus_clean = tokenizer(docs, join_tokens=True)
corpus_clean
# Out:
# ['coffee tasty', 'tea smell taste well coffee', 'good smell coffee smell']

# %%
cv = CountVectorizer(ngram_range=(1, 1),
                     max_df=1.0,
                     min_df=1,
                     max_features=None,
                     binary=False)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_raw,
                  columns=cv.get_feature_names_out())
df
# Out:
#                                            coffee  good  smell  taste  tasty  \
# This coffee is really really tasty.             1     0      0      0      1
# Tea smells and tastes better than coffee.       1     0      1      1      0
# Best smelling coffee I have ever smelled!       1     1      2      0      0
#
#                                            tea  well
# This coffee is really really tasty.          0     0
# Tea smells and tastes better than coffee.    1     1
# Best smelling coffee I have ever smelled!    0     0

# %%
cv = CountVectorizer(ngram_range=(2, 2),  # use (1, 2) for unigrams *and* bigrams
                     max_df=1.0,
                     min_df=1,
                     max_features=None,
                     binary=False)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_clean,
                  columns=cv.get_feature_names_out())
df
# Out:
#                              coffee smell  coffee tasty  good smell  \
# coffee tasty                            0             1           0
# tea smell taste well coffee             0             0           0
# good smell coffee smell                 1             0           1
#
#                              smell coffee  smell taste  taste well  tea smell  \
# coffee tasty                            0            0           0          0
# tea smell taste well coffee             0            1           1          1
# good smell coffee smell                 1            0           0          0
#
#                              well coffee
# coffee tasty                           0
# tea smell taste well coffee            1
# good smell coffee smell                0

# %% [markdown]
# Now these vectors are a bit more meaningful.

# %% [markdown]
# ### TFIDF Vectorizer
#
# Downsides of Count Vectorizer:
#
# - Counts can be too simplistic
# - High counts can dominate, especially for high frequency words or long documents
# - Each word is treated equally, when some terms might be more "important" than others
#
# We define TFIDF as:
#
# $$
# \begin{align*}
# \text{tf-idf} &= \text{term frequency} * \text{inverse document frequency} \\
# \text{term frequency} &= \frac{\text{term count in document}}{\text{total terms in document}} \\
# \text{inverse document frequency} &= \log\bigg(\frac{\text{total number of documents} + 1}{\text{number of documents with term} + 1}\bigg)
# \end{align*}
# $$

# %% [markdown]
# This measure is calculated for every term-document combination:
# - It captures how common a word is relative to the words in its document (i.e., term frequency)
# - Rare words get additional weight (e.g., small denominator in the inverse document frequency)
# - The $\log$ dampens the effect of the inverse document frequency as the denominator gets very small or the numerator gets very large.

# %%
cv = TfidfVectorizer(max_df=1.0,
                     min_df=1,
                     max_features=None)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_clean,
                  columns=cv.get_feature_names_out())

# %%
sns.heatmap(df, square=True, cmap='Blues', annot=True, cbar=False);

# %% [markdown]
# ## Topic Modeling
#
# ### Matrix Decomposition
#
# The document term matrix $X$ is a matrix just like any other in Linear Algebra. Just so, it defines a row space (the documents represented as linear combinations of terms), and column space (terms represented as a linear combination of documents). With this, there are a few matrix decomposition methods we can use to extract further information about these documents and terms.

# %%
from sklearn.decomposition import TruncatedSVD, NMF, PCA

# %% [markdown]
# ### Singular Value Decomposition
#
# Singular Value Decomposition is a guaranteed decomposition for any rectangular matrix. It creates the following equality:
#
# $$
# X = U\Sigma V^\top
# $$
#
# **Breifly**:
# - Each row of $U$ represents the corresponding document in terms of "topics directions" along the columns.
# - The rows of $V$ (columns of $V^\top$) represent similarly represented version of the terms.
# - The $\Sigma$ matrix contains the "variance explained" by each of these topics, sorted in descending order.
#
# As far as naming goes:
#
# - The analysis of these resulting matrices is called **Principal Components Analysis (PCA)**.
# - When used with text data, this analysis is called **Latent Semantic Analysis (LSA)**.

# %%
corpus = tokenizer(df_coffee['spacy_doc'], join_tokens=True)

# %%
cv = TfidfVectorizer(max_df=0.9,
                     min_df=0.1,
                     max_features=None)

X = cv.fit_transform(corpus)
# df = pd.DataFrame(X, index=corpus, columns=cv.get_feature_names_out())

# %% [markdown]
# Note, we use `TruncatedSVD` here because it's a more efficient implementation of SVD. PCA centers the data before running the algorithm, which is more "appropriate" but takes more time. This does cause a few inconsistencies in the "sorted" $\Sigma$.

# %%
lsa = TruncatedSVD(n_components=5)  # results only change for larger (unseen) values

doc_topic = lsa.fit_transform(X)
lsa.explained_variance_ratio_
# Out:
# array([0.00488584, 0.08197821, 0.04773752, 0.04683695, 0.03503009])

# %%
topic_term = pd.DataFrame(lsa.components_.round(3),
                          columns = cv.get_feature_names_out())

topic_term
# Out:
#    acidity  almond   bake  balanced  bright  brisk  butter  cedar  center  \
# 0    0.192   0.124  0.090     0.103   0.117  0.072   0.068  0.167   0.082
# 1    0.072  -0.025 -0.142     0.065   0.120 -0.018  -0.019 -0.109  -0.003
# 2    0.042   0.064  0.307    -0.042  -0.124  0.198   0.059  0.140  -0.008
# 3   -0.120   0.008 -0.109    -0.008   0.008 -0.083   0.034  0.071  -0.013
# 4   -0.084  -0.150 -0.116     0.018  -0.164 -0.027  -0.081 -0.077  -0.061
#
#    chocolate  ...  sweet  sweetly  syrup  syrupy   tart   tone  undertone  \
# 0      0.256  ...  0.280    0.146  0.079   0.144  0.195  0.248      0.077
# 1     -0.460  ...  0.034    0.030  0.041   0.038  0.113  0.032     -0.017
# 2     -0.067  ...  0.102   -0.060  0.060  -0.147 -0.111  0.107      0.059
# 3     -0.033  ... -0.171   -0.040 -0.043  -0.042  0.030  0.098      0.008
# 4     -0.070  ...  0.085   -0.145 -0.063   0.044 -0.376 -0.070      0.033
#
#    velvety  vibrant   zest
# 0    0.070    0.066  0.148
# 1   -0.046    0.071  0.040
# 2    0.126   -0.089  0.018
# 3   -0.013   -0.018  0.007
# 4    0.019   -0.049 -0.060
#
# [5 rows x 65 columns]

# %%
# the third "topic"
topic = 0
n_terms = 10

topic_term.T[topic].abs().sort_values(ascending=False).iloc[:n_terms]
# Out:
# sweet        0.280
# chocolate    0.256
# tone         0.248
# cocoa        0.219
# tart         0.195
# structure    0.193
# acidity      0.192
# note         0.174
# cedar        0.167
# dark         0.159
# Name: 0, dtype: float64

# %%
# the third "topic"
topic = 1
n_terms = 10

topic_term.T[topic].abs().sort_values(ascending=False).iloc[:n_terms]
# Out:
# cocoa        0.476
# chocolate    0.460
# nib          0.386
# dark         0.304
# chocolaty    0.245
# milk         0.165
# espresso     0.164
# evaluate     0.161
# small        0.160
# bake         0.142
# Name: 1, dtype: float64

# %% [markdown]
# **<span style = "color: darkorange;"> What about negative values? </span>**

# %% [markdown]
# ### Non-Negative Matrix Factorization
#
# [NMF](https://en.wikipedia.org/wiki/Non-negative_matrix_factorization) is very similar to SVD. Here, we have the following decomposition.
#
# $$
# X = WH
# $$
#
# In this case though, all values in $W$ and $H$ are positive, and we can *approximate* this decomposition because all values in $X$ are positive.

# %%
nmf = NMF(4)  # here, the number will change the results
doc_topic = nmf.fit_transform(X)

# %%
topic_term = pd.DataFrame(nmf.components_.round(3),
                          columns = cv.get_feature_names_out())

topic_term
# Out:
#    acidity  almond   bake  balanced  bright  brisk  butter  cedar  center  \
# 0    0.935   0.390  0.000     0.612   0.863  0.000   0.084  0.017   0.353
# 1    0.000   0.173  0.000     0.046   0.000  0.000   0.132  0.617   0.113
# 2    0.546   0.483  0.959     0.103   0.000  0.609   0.300  0.657   0.210
# 3    0.492   0.164  0.000     0.364   0.488  0.018   0.112  0.284   0.167
#
#    chocolate  ...  sweet  sweetly  syrup  syrupy   tart   tone  undertone  \
# 0      0.822  ...  1.423    0.902  0.233   1.220  1.005  0.604      0.089
# 1      1.568  ...  0.029    0.133  0.000   0.176  0.177  0.399      0.185
# 2      0.710  ...  0.896    0.237  0.293   0.031  0.198  0.699      0.274
# 3      0.000  ...  0.504    0.334  0.230   0.309  0.704  0.737      0.193
#
#    velvety  vibrant   zest
# 0    0.000    0.557  0.651
# 1    0.119    0.000  0.136
# 2    0.438    0.000  0.352
# 3    0.048    0.261  0.378
#
# [4 rows x 65 columns]

# %%
# the third "topic"
topic = 0
n_terms = 10

topic_term.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# savory        2.346
# sweet         1.423
# long          1.284
# flavor        1.231
# syrupy        1.220
# juicy         1.124
# sandalwood    1.122
# structure     1.109
# resonant      1.048
# richly        1.024
# Name: 0, dtype: float64

# %%
# the third "topic"
topic = 1
n_terms = 10

topic_term.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# chocolate    1.568
# dark         1.294
# milk         1.136
# espresso     1.132
# evaluate     1.104
# small        1.102
# chocolaty    1.015
# cedar        0.617
# fruit        0.524
# floral       0.492
# Name: 1, dtype: float64

# %% [markdown]
# As you can tell, this often produces more agreeable results than LSA.

# %% [markdown]
# ### Latent Dirichlet Allocation (LDA)
#
# LDA is a "generative" model that builds topics with the assumption that documents are generated based on a probability distribution of topics, and that topics are just a probability distribution of terms.

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
# these parameters require tuning ...
lda = LatentDirichletAllocation(n_components=5,
                                max_iter=50)

X_topics = lda.fit_transform(X)

# %%
df_lda = pd.DataFrame(data = X_topics,
                      index = corpus)

# %%
# the third "topic"
topic = 0
n_docs = 3

for d in df_lda[topic].sort_values(ascending=False).iloc[:n_docs].index:
    print(d, '\n')
# Out:
# rich toned deeply sweetly earthy chocolate fudge white sage blackberry perique pipe tobacco plumeria like flower aroma cup balanced sweet savory structure vibrant juicy acidity delicate satiny mouthfeel resonant flavor saturate finish display note blackberry tobacco short plumeria sage long deep chocolate
#
# richly sweet spice tone dry cherry lemon zest baker chocolate cashew hint cayenne aroma cup delicate sweetly tart structure bright acidity crisp velvety mouthfeel flavor saturate finish center citrus note chocolate short suggestion cayenne long
#
# crisply sweet spice tone dry papaya caramel tangerine zest pink peppercorn vanilla aroma cup high tone sweetly tart structure juicy bright acidity lean satiny smooth mouthfeel resonant richly dry finish laden sweet note caramel papaya short turn savory lean long hint pink peppercorn wrap vanilla

# %%
# the third "topic"
topic = 1
n_docs = 3

for d in df_lda[topic].sort_values(ascending=False).iloc[:n_docs].index:
    print(d, '\n')
# Out:
# crisply sweet fruit tone raspberry fresh cut fir maple syrup cocoa powder freesia like flower aroma cup sweet structure brisk acidity satiny smooth mouthfeel gently dry finish center quiet note raspberry fir
#
# delicate richly sweet fruit center dry strawberry baker chocolate magnolia fresh cut fir maple syrup aroma cup sweet tone structure brisk acidity smooth satiny mouthfeel finish consolidate note dry strawberry fresh cut fir crisp chocolate undertone
#
# delicate crisply sweet tart lime zest baker chocolate plum fresh cut fir hint apple brandy aroma cup richly bittersweet structure brisk acidity satiny mouthfeel finish consolidate note lime zest aromatic wood whisper fruit tone sweet ferment

# %%
df_lda_terms = pd.DataFrame(data = lda.components_,
                            columns = cv.get_feature_names_out())

# %%
# the third "topic"
topic = 0
n_terms = 10

df_lda_terms.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# chocolate     101.033380
# savory         94.750382
# dark           86.249478
# sweet          80.362850
# sandalwood     71.432099
# structure      62.792699
# tart           61.633377
# flavor         56.361521
# juicy          56.046942
# tone           55.880879
# Name: 0, dtype: float64

# %%
# the third "topic"
topic = 1
n_terms = 10

df_lda_terms.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# fresh      93.371331
# cut        74.890213
# oak        73.093144
# sweet      41.511522
# nut        38.027043
# brisk      34.048280
# tone       30.348093
# crisply    27.419471
# gently     26.364764
# zest       24.825095
# Name: 1, dtype: float64

# %% [markdown]
# ### Anchored Correlation Explanation (CorEx)
#
# [CorEx](https://github.com/gregversteeg/corex_topic) is a discriminative model, which starts from $X$ (documents/words) to determine $Y$ (topics). CorEx looks for groups of words that are in the same topic, a.k.a. have high Total Correlation (TC), or convey the same information.
#
# - If words are **tightly related** (always appear together in the same topic/document), TC will be high. This is a good topic.
# - If the words are all **independent** (never appear together in the same document or topic), TC = 0. This is a bad topic.
# - CorEx creates a partition across terms. I.e., **terms can only occur in a single topic**.
#
# CorEx roughly follows this algorithm:
# 1. Look for a group of words that are both as broad (in many documents) and overlapping as possible (both together will lead to high TC), and call this a topic.
# 2. Repeat the process for another set of words (not overlapping with your previous group) with as high a TC as possible, and call this the next topic.
#
# As we create more topics, each subsequent topic will have lower TC.

# %%
from corextopic import corextopic as ct

# %%
topic_model = ct.Corex(n_hidden=5,                        # number of topics
                       words=cv.get_feature_names_out(),  # list of terms in corpus
                       seed=1)

topic_model.fit(X, words=cv.get_feature_names_out(), docs=corpus)

# %%
# Print all topics from the CorEx topic model
topics = topic_model.get_topics()
for n,topic in enumerate(topics):
    topic_words,_,_ = zip(*topic)
    print('{}: '.format(n) + ','.join(topic_words))
# Out:
# 0: espresso,evaluate,small,milk,chocolaty,nib,chocolate,cocoa,dark,juicy
# 1: almond,brisk,crisp,cut,like
# 2: deeply,fruit,richly,round,satiny,undertone
# 3: fresh,hint,sandalwood,zest
# 4: crisply,flower,gently,note,oak,rich,tone

# %% [markdown]
# Take a look at how you can use [anchor words](https://github.com/gregversteeg/corex_topic/tree/master#using-anchor-words) to guide the topic creation.

# %% [markdown]
# ## ScatterText
#
# Scattertext is great for
# - Visually inspecting text
# - Comparing/Contrasting corpora
# - And more...
#
# Check out Jason Kessler's GitHub project for more information: [here](https://github.com/JasonKessler/scattertext).

# %%
import scattertext as st

# %%
convention_df = st.SampleCorpora.ConventionData2012.get_data()

# %%
convention_df.head()
# Out:
#       party                                               text         speaker
# 0  democrat  Thank you. Thank you. Thank you. Thank you so ...    BARACK OBAMA
# 1  democrat  Thank you so much. Tonight, I am so thrilled a...  MICHELLE OBAMA
# 2  democrat  Thank you. It is a singular honor to be here t...  RICHARD DURBIN
# 3  democrat  Hey, Delaware. \nAnd my favorite Democrat, Jil...    JOSEPH BIDEN
# 4  democrat  Hello. \nThank you, Angie. I'm so proud of how...      JILL BIDEN

# %%
corpus = st.CorpusFromPandas(convention_df,
                             category_col='party',
                             text_col='text',
                             nlp=st.whitespace_nlp_with_sentences
                            ).build()

# %%
html = st.produce_scattertext_explorer(
        corpus,
        category='democrat',
        category_name='Democratic',
        not_category_name='Republican',
        minimum_term_frequency=10,
        pmi_threshold_coefficient=5,
        width_in_pixels=1000,
        metadata=convention_df['speaker'],
        )

# %%
with open('demo.html', 'wb') as f:
    f.write(html.encode('utf-8'))

# %% [markdown]
# ## Sentiment Analysis with VADER
#
# According to the documentation:
#
#     VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media. [...]
#
#     Sentiment ratings from 10 independent human raters (all pre-screened, trained, and quality checked for optimal inter-rater reliability). Over 9,000 token features were rated on a scale from "[–4] Extremely Negative" to "[4] Extremely Positive", with allowance for "[0] Neutral (or Neither, N/A)".

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
sentences = ["VADER is smart, handsome, and funny.",  # positive sentence example
             "VADER is smart, handsome, and funny!",  # punctuation emphasis handled correctly (sentiment intensity adjusted)
             "VADER is very smart, handsome, and funny.", # booster words handled correctly (sentiment intensity adjusted)
             "VADER is VERY SMART, handsome, and FUNNY.",  # emphasis for ALLCAPS handled
             "VADER is VERY SMART, handsome, and FUNNY!!!", # combination of signals - VADER appropriately adjusts intensity
             "VADER is VERY SMART, uber handsome, and FRIGGIN FUNNY!!!", # booster words & punctuation make this close to ceiling for score
             "VADER is not smart, handsome, nor funny.",  # negation sentence example
             "The book was good.",  # positive sentence
             "At least it isn't a horrible book.",  # negated negative sentence with contraction
             "The book was only kind of good.", # qualified positive sentence is handled correctly (intensity adjusted)
             "The plot was good, but the characters are uncompelling and the dialog is not great.", # mixed negation sentence
             "Today SUX!",  # negative slang with capitalization emphasis
             "Today only kinda sux! But I'll get by, lol", # mixed sentiment example with slang and constrastive conjunction "but"
             "Make sure you :) or :D today!",  # emoticons handled
             # "Catch utf-8 emoji such as such as 💘 and 💋 and 😁",  # emojis handled, ignored for seaborn plot below
             "Not bad at all"  # Capitalized negation
             ]

# %%
df_sentiment = []

analyzer = SentimentIntensityAnalyzer()

for sentence in sentences:
    vs = analyzer.polarity_scores(sentence)
    df_sentiment.append(vs)

# %%
df_sentiment = pd.DataFrame(df_sentiment,
                            index = sentences)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 2
#       1 df_sentiment = pd.DataFrame(df_sentiment,
# ----> 2                             index = range(len(chunk_clean)))
#
# NameError: name 'chunk_clean' is not defined

# %%
sns.heatmap(df_sentiment, cmap='Blues', annot=True, cbar=False, linewidths=1);
# Out:
# ) missing from current font.vs\i501-nlp\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 13 (
#   fig.canvas.draw()
# ) missing from current font.vs\i501-nlp\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 13 (
#   func(*args, **kwargs)
# ) missing from current font.vs\i501-nlp\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # EXERCISES

# %% [markdown]
# ## Exercise 1
#
# Using a book from [Project Gutenberg](https://www.gutenberg.org/), get the text data directly from its URL using the `requests` package. Break the book into about 50 sensible "chunks" like chapters or paragraphs, organizing them into a list.
#
# Load this data into a spaCy pipeline and analyze either Named Entities or Parts of Speech in each chunk.
#
# Provide your analysis: What types of entities or parts of speech are common, and what are uncommon? What insights can you draw from these patterns?
#
# *Note*: Do not download any file, make use of URL in your code.

# %% [markdown]
# ## My Code
# First I will download the book from the gutenburg project website. I've chosen the book I am currently reading, Candide, by Voltare

# %%
# write your code here ...

import requests
url = 'https://www.gutenberg.org/cache/epub/19942/pg19942.txt'
response = requests.get(url)
book_text = response.text

# %% [markdown]
# Next I need to break the book up into chunks. To do this I will divide the text into 50 equal size chunks

# %%
def split_text_into_chunks(text, num_chunks):
    chunk_size = len(text) // num_chunks
    chunks = [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]
    
    # Adjust the last chunk in case of any remainder
    if len(chunks) > num_chunks:
        chunks[-2] += chunks[-1]
        chunks = chunks[:-1]
    elif len(chunks) < num_chunks:
        # In case where we have less chunks than requested
        chunks.append('')
        
    return chunks

chunks = split_text_into_chunks(book_text, 10)

# %% [markdown]
# we should now have 10 chunks

# %%
len(chunks)
# Out:
# 10

# %% [markdown]
# Now that we have our chunks, I will load it into a spacy pipeline and tokenize the text.

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

docs = nlp.pipe(chunks)

def tokenizer(docs, join_tokens=False):
    '''
    Tokenize an iterable of spaCy `docs`.

    join_tokens : bool
        Whether we want to return a list of strings or
        a list of lists. If True, join with space (" ").
    '''
    docs_clean = []

    for doc in docs:
        # collect only filtered words from each document
        tokens = [w.lemma_.lower() for w in doc if
                  (not w.is_stop
                   and not w.is_punct
                   and not w.like_num) \
                  or (w.lemma_ == 'not')]

        if join_tokens:
            docs_clean.append(' '.join(tokens))
        else:
            docs_clean.append(tokens)

    return docs_clean


chunks_clean = tokenizer(docs, join_tokens = True)
chunks_clean
# Out:
# ['\ufeffthe project gutenberg ebook candide \r\n    \r\n ebook use united states \r\n part world cost restriction \r\n whatsoever copy away use term \r\n project gutenberg license include ebook online \r\n www.gutenberg.org not locate united states \r\n check law country locate \r\n ebook \r\n\r\n title candide \r\n\r\n\r\n author voltaire \r\n\r\n release date november ebook \r\n\r\n language english \r\n\r\n credit produce chuck greif fox stars online \r\n         distribute proofreading team http://www.pgdp.net \r\n\r\n\r\n start project gutenberg ebook candide \r\n\r\n\r\n\r\n\r\n produce chuck greif fox stars online \r\n distribute proofreading team http://www.pgdp.net \r\n\r\n\r\n\r\n\r\n\r\n                                    \r\n     + ------------------------------------------------------------+ \r\n     | transcriber note                                         | \r\n     |                                                             | \r\n     | obvious typographical error correct         | \r\n     | text complete list    | \r\n     | document                                              | \r\n     |                                                             | \r\n     + ------------------------------------------------------------+ \r\n\r\n                                    \r\n\r\n\r\n\r\n modern library \r\n\r\n world best books \r\n\r\n\r\n\r\n\r\n candide voltaire \r\n\r\n\r\n      publishers glad mail complete list title \r\n      modern library list representative \r\n      great moderns important contribution \r\n      publish year \r\n      reader book find title need low price \r\n      attractive form \r\n\r\n\r\n illustration voltaire \r\n\r\n\r\n\r\n\r\n candide \r\n\r\n voltaire \r\n\r\n introduction philip littell \r\n\r\n boni liveright inc \r\n\r\n publishers new york \r\n\r\n copyright \r\n boni liveright inc \r\n\r\n printed united states america \r\n\r\n\r\n\r\n\r\n introduction \r\n\r\n\r\n voltaire write candide ridicule notion \r\n good possible world world \r\n gayer place reader voltaire write day \r\n generation find laughter not grow old \r\n\r\n candide not age different book look \r\n voltaire write year later \r\n thing book sight sound \r\n modern writer try catch fix word \r\n atlantic change break atlantic monotony voyage \r\n cadiz buenos ayres martin candide sail length \r\n mediterranean contrast naked scarped \r\n balearic cliff headland calabria mist \r\n quarter distance far horizon alter silhouette \r\n ionian island colored bird fill paraguay \r\n silver acid cry \r\n\r\n dr. pangloss prove existence design universe say \r\n nose carry spectacle spectacle \r\n modern satirist not try paint voltaire quick brush \r\n doctrine want expose choose \r\n complicated doctrine dr. pangloss optimism study \r\n closely feel destructive way learned \r\n caress malice attack stealthy flexible patient \r\n voltaire especially learning get \r\n little control patient \r\n bore candide bore anybody william wordsworth \r\n\r\n voltaire man woman point case optimism start \r\n high fall low modern not fashion \r\n not plunge people unfamiliar misery \r\n misery bear \r\n\r\n account voltaire procedure misleading \r\n plaster cast dance look procedure mademoiselle \r\n cunégonde illustrious westphalian spring family \r\n prove quartering descend descend find \r\n earn wash dish propontis aged faithful \r\n attendant victim act rape negro pirate remember \r\n daughter pope honor \r\n approach marriage prince massa carrara italy write \r\n sonnet not passable not need know french \r\n literature voltaire order feel lurk parody \r\n escape poke fun laughter \r\n method grow unmistakable \r\n caricature casually assemble fall monarch inn \r\n venice \r\n\r\n modern assailant optimism arm social pity \r\n social pity candide voltaire light touch familiar \r\n institution open reveal absurdity like remind \r\n slaughter pillage murder candide witness \r\n bulgarians perfectly regular having conduct  ...
r\n inquisitor prudent old woman see \r\n\r\n not run away say cunegonde \r\n fear not kill lord governor \r\n love not suffer ill treat stay \r\n\r\n run immediately candide \r\n\r\n fly say hour burn \r\n\r\n not moment lose cunegonde \r\n flee shelter \r\n\r\n\r\n\r\n\r\n xiv \r\n\r\n candide cacambo receive jesuit paraguay \r\n\r\n\r\n candide bring valet cadiz meet \r\n coast spain american colony \r\n quarter spaniard bear mongrel tucuman singing boy \r\n sacristan sailor monk pedlar soldier lackey \r\n cacambo love master master good \r\n man quickly saddle andalusian horse \r\n\r\n come master let follow old woman advice let start \r\n run look \r\n\r\n candide shed tear \r\n\r\n oh dear cunegonde leave time \r\n governor go sanction nuptial cunegonde bring \r\n distance \r\n\r\n say cacambo woman \r\n loss god provide let run \r\n\r\n art thou carry shall shall \r\n cunegonde say candide \r\n\r\n st. james compostella s ...
#  'jesuit jesuit \r\n\r\n candide not help surprised cause deliverance \r\n\r\n people say man manner not \r\n lucky run miss cunegonde brother body \r\n devour redemption pure nature good \r\n people instead feast flesh show \r\n civility not jesuit \r\n\r\n\r\n\r\n\r\n xvii \r\n\r\n arrival candide valet el dorado see \r\n\r\n\r\n say cacambo candide soon reach \r\n frontier oreillons hemisphere not well \r\n word let europe short \r\n way \r\n\r\n say candide shall country \r\n bulgarians abares slay portugal \r\n shall burn abide moment danger \r\n spit resolve quit world \r\n dear cunegonde reside \r\n\r\n let turn cayenne say cacambo shall find \r\n frenchmen wander world assist god \r\n pity \r\n\r\n not easy cayenne know vaguely direction \r\n river precipice robber savage obstruct \r\n way horse die fatigue provision consume \r\n feed month wild fruit find near \r\n little river border cocoa tree sustain life \r\n hope \r\n\r\n cacambo good counsellor old woman say candide \r\n\r\n able hold long walk \r\n canoe near river let fill cocoanut throw \r\n current river lead \r\n inhabit spot not find pleasant thing shall find \r\n new thing \r\n\r\n heart say candide let recommend \r\n providence \r\n\r\n row league bank place flowery \r\n barren part smooth rugge stream \r\n widen length lose arch frightful rock \r\n reach sky traveller courage commit \r\n current river suddenly contract \r\n place whirl dreadful noise rapidity end \r\n hour see daylight canoe \r\n dash piece rock league creep \r\n rock rock length discover extensive plain \r\n bound inaccessible mountain country cultivate \r\n pleasure necessity side useful \r\n beautiful road cover adorn carriage \r\n glitter form substance man woman \r\n surprising beauty draw large red sheep surpass fleetness \r\n fine courser andalusia tetuan mequinez.[18 \r\n\r\n country say candide well \r\n westphalia \r\n\r\n step cacambo village see \r\n child dress tattered brocade play quoit outskirt \r\n traveller world amuse look \r\n quoit large round piece yellow red green cast \r\n singular lustre traveller pick ground \r\n gold emerald ruby \r\n great ornament mogul throne \r\n\r\n doubt say cacambo child king son \r\n play quoit \r\n\r\n village schoolmaster appear moment call \r\n school \r\n\r\n say candide preceptor royal family \r\n\r\n little truant immediately quit game leave quoit \r\n ground plaything candide gather \r\n run master present humble manner \r\n give understand sign royal highness \r\n forget gold jewel schoolmaster smile fling \r\n ground look candide good deal surprise \r\n go business \r\n\r\n traveller take care gather gold ruby \r\n emerald \r\n\r\
\r\n     | hyphenate unhyphenated version            | \r\n     | word retain dung hill dunghill         | \r\n     | new comer newcomer                                   | \r\n     |                                                             | \r\n     | single footnote page move                 | \r\n     | endnote note number indexed        | \r\n     | page reference add moved footnote           | \r\n     | match format endnote                         | \r\n     |                                                             | \r\n     | modern library blurb mail complete list title leave   | \r\n     |                                                      | \r\n     |                                                             | \r\n     | instance massa carara pp     | \r\n     | instance massa carrara page ix        | \r\n     | introduction i.e. distinct book | \r\n     | proper retain                               | \r\n     |                                                             | \r\n     | different spelling cunégonde occur     | \r\n     | introduction robeck occur        | \r\n     | note p. spelt robek text p.       | \r\n     | retain reason                          | \r\n     |                                                             | \r\n     + ------------------------------------------------------------+ \r\n\r\n                                    \r\n\r\n\r\n\r\n\r\n\r\n\r\n        \r\n             end project gutenberg ebook candide \r\n        \r\n\r\n    \r\n\r\n update edition replace previous old edition \r\n rename \r\n\r\n create work print edition not protect u.s. copyright \r\n law mean own united states copyright work \r\n foundation copy distribute united \r\n states permission pay copyright \r\n royalty special rule set forth general term use \r\n license apply copying distribute project \r\n gutenberg ™ electronic work protect project gutenberg ™ \r\n concept trademark project gutenberg register trademark \r\n not charge ebook follow \r\n term trademark license include pay royalty use \r\n project gutenberg trademark not charge \r\n copy ebook comply trademark license \r\n easy use ebook nearly purpose creation ...

# %% [markdown]
# Now that we have tokenized our data and cleaned it, we can vectorize our tokens to understand the relationships between them.

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd

cv = TfidfVectorizer(max_df=3,
                     min_df=3,
                     max_features=None)

X = cv.fit_transform(chunks_clean)

df = pd.DataFrame(X.toarray(),
                  index=chunks_clean,
                  columns=cv.get_feature_names_out())

# %% [markdown]
# We can further analyze the relationships by creating an Anchored Correlation Explanation model. This will tell us which words are tightly related and which words are more independent.

# %%
from corextopic import corextopic as ct

topic_model = ct.Corex(n_hidden=10,                        # number of topics
                       words=cv.get_feature_names_out(),  # list of terms in corpus
                       seed=1)

topic_model.fit(X, words=cv.get_feature_names_out(), docs=chunks_clean)

# %%
# Print all topics from the CorEx topic model
topics = topic_model.get_topics()
for n,topic in enumerate(topics):
    topic_words,_,_ = zip(*topic)
    print('{}: '.format(n) + ','.join(topic_words))
# Out:
# 0: abbé,piastre,skipper,paris,tragedy,breakfast,preacher,pride,prison,propose
# 1: voltaire,practice,power,plain,overwhelm,oreillons,oppose,necessity,necessarily,mr
# 2: copy,provide,advance,stuff,snow,slight,scene,sage,road,read
# 3: abominable,massacre,oath,particular,preach,provision,renounce,ride,mass,round
# 4: abares,march,match,melancholy,miserable,paraguay,party,passenger,lip,plunge
# 5: acre,usual,troop,tongue,theodore,suit,story,sciences,resolve,prepare
# 6: amend,ornament,pleased,polite,pour,powerful,profit,oblige,proper,saddle
# 7: bacon,shore,render,prisoner,principle,pair,pain,neighborhood,midst,linen
# 8: advantage,transport,slay,repeat,reasonable,propontis,prevail,philosophy,paper,palpitating
# 9: james,sailor,undergo,spit,sin,sex,row,room,robe,religious

# %% [markdown]
# Set 0 are the most tightly related words, Set 1 is the next more related, and so on.

# %% [markdown]
# ## Exercise 2
#
# Apply spaCy to extract the most meaningful content from your documents, considering options like excluding stop words or focusing on nouns (i.e. preprocessing and filtering).
#
# Perform a sentiment analysis on the refined data. Create visualization of your result.
#
# Summarize your results by explaining how sentiment changes across sections.

# %% [markdown]
# ## My Code

# %% [markdown]
# To extract the most meaningful content from our text chunks we need to tell spacy to remove stop words. Our tokenizer function that we created in Exercise 1 removes stop words so we can use that again.

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

docs = nlp.pipe(chunks)

def tokenizer(docs, join_tokens=False):
    '''
    Tokenize an iterable of spaCy `docs`.

    join_tokens : bool
        Whether we want to return a list of strings or
        a list of lists. If True, join with space (" ").
    '''
    docs_clean = []

    for doc in docs:
        # collect only filtered words from each document
        tokens = [w.lemma_.lower() for w in doc if
                  (not w.is_stop
                   and not w.is_punct
                   and not w.like_num) \
                  or (w.lemma_ == 'not')]

        if join_tokens:
            docs_clean.append(' '.join(tokens))
        else:
            docs_clean.append(tokens)

    return docs_clean


chunks_clean = tokenizer(docs, join_tokens = True)
chunks_clean
# Out:
# ['\ufeffthe project gutenberg ebook candide \r\n    \r\n ebook use united states \r\n part world cost restriction \r\n whatsoever copy away use term \r\n project gutenberg license include ebook online \r\n www.gutenberg.org not locate united states \r\n check law country locate \r\n ebook \r\n\r\n title candide \r\n\r\n\r\n author voltaire \r\n\r\n release date november ebook \r\n\r\n language english \r\n\r\n credit produce chuck greif fox stars online \r\n         distribute proofreading team http://www.pgdp.net \r\n\r\n\r\n start project gutenberg ebook candide \r\n\r\n\r\n\r\n\r\n produce chuck greif fox stars online \r\n distribute proofreading team http://www.pgdp.net \r\n\r\n\r\n\r\n\r\n\r\n                                    \r\n     + ------------------------------------------------------------+ \r\n     | transcriber note                                         | \r\n     |                                                             | \r\n     | obvious typographical error correct         | \r\n     | text complete list    | \r\n     | document                                              | \r\n     |                                                             | \r\n     + ------------------------------------------------------------+ \r\n\r\n                                    \r\n\r\n\r\n\r\n modern library \r\n\r\n world best books \r\n\r\n\r\n\r\n\r\n candide voltaire \r\n\r\n\r\n      publishers glad mail complete list title \r\n      modern library list representative \r\n      great moderns important contribution \r\n      publish year \r\n      reader book find title need low price \r\n      attractive form \r\n\r\n\r\n illustration voltaire \r\n\r\n\r\n\r\n\r\n candide \r\n\r\n voltaire \r\n\r\n introduction philip littell \r\n\r\n boni liveright inc \r\n\r\n publishers new york \r\n\r\n copyright \r\n boni liveright inc \r\n\r\n printed united states america \r\n\r\n\r\n\r\n\r\n introduction \r\n\r\n\r\n voltaire write candide ridicule notion \r\n good possible world world \r\n gayer place reader voltaire write day \r\n generation find laughter not grow old \r\n\r\n candide not age different book look \r\n voltaire write year later \r\n thing book sight sound \r\n modern writer try catch fix word \r\n atlantic change break atlantic monotony voyage \r\n cadiz buenos ayres martin candide sail length \r\n mediterranean contrast naked scarped \r\n balearic cliff headland calabria mist \r\n quarter distance far horizon alter silhouette \r\n ionian island colored bird fill paraguay \r\n silver acid cry \r\n\r\n dr. pangloss prove existence design universe say \r\n nose carry spectacle spectacle \r\n modern satirist
moustachio smile mockingly order captain \r\n candide review company candide obey governor \r\n remain miss cunegonde declare passion protest \r\n marry day face church \r\n agreeable cunegonde ask quarter \r\n hour consider consult old woman \r\n resolution \r\n\r\n old woman speak cunegonde \r\n\r\n miss quartering not farthing \r\n power wife great lord south america \r\n beautiful moustachio pique \r\n inviolable fidelity ravish bulgarians jew \r\n inquisitor enjoy favour misfortune give sufficient \r\n excuse place scruple \r\n marry governor make fortune captain candide \r\n\r\n old woman speak prudence age experience \r\n give small ship enter port board alcalde \r\n alguazil happen \r\n\r\n old woman shrewdly guess grey friar steal \r\n cunegonde money jewel town badajos \r\n candide escape friar want sell diamond \r\n jeweller jeweller know grand inquisitor \r\n friar hang confess steal describe \r\n person route take flight cunegonde \r\n candide know trace cadiz vessel \r\n immediately send pursuit vessel port \r\n buenos ayres report spread alcalde go land \r\n pursuit murderer lord grand \r\n inquisitor prudent old woman see \r\n\r\n not run away say cunegonde \r\n fear not kill lord governor \r\n love not suffer ill treat stay \r\n\r\n run immediately candide \r\n\r\n fly say hour burn \r\n\r\n not moment lose cunegonde \r\n flee shelter \r\n\r\n\r\n\r\n\r\n xiv \r\n\r\n candide cacambo receive jesuit paraguay \r\n\r\n\r\n candide bring valet cadiz meet \r\n coast spain american colony \r\n quarter spaniard bear mongrel tucuman singing boy \r\n sacristan sailor monk pedlar soldier lackey \r\n cacambo love master master good \r\n man quickly saddle andalusian horse \r\n\r\n come master let follow old woman advice let start \r\n run look \r\n\r\n candide shed tear \r\n\r\n oh dear cunegonde leave time \r\n governor go sanction nuptial cunegonde bring \r\n distance \r\n\r\n say cacambo woman \r\n loss god provide let run \r\n\r\n art thou carry shall shall \r\n cunegonde say candide \r\n\r\n st. james compostella s ...
#  'jesuit jesuit \r\n\r\n candide not help surprised cause deliverance \r\n\r\n people say man manner not \r\n lucky run miss cunegonde brother body \r\n devour redemption pure nature good \r\n people instead feast flesh show \r\n civility not jesuit \r\n\r\n\r\n\r\n\r\n xvii \r\n\r\n arrival candide valet el dorado see \r\n\r\n\r\n say cacambo candide soon reach \r\n frontier oreillons hemisphere not well \r\n word let europe short \r\n way \r\n\r\n say candide shall country \r\n bulgarians abares slay portugal \r\n shall burn abide moment danger \r\n spit resolve quit world \r\n dear cunegonde reside \r\n\r\n let turn cayenne say cacambo shall find \r\n frenchmen wander world assist god \r\n pity \r\n\r\n not easy cayenne know vaguely direction \r\n river precipice robber savage obstruct \r\n way horse die fatigue provision consume \r\n feed month wild fruit find near \r\n little river border cocoa tree sustain life \r\n hope \r\n\r\n cacambo good counsellor old woman say candide \r\n\r\n able hold long walk \r\n canoe near river let fill cocoanut throw \r\n current river lead \r\n inhabit spot not find pleasant thing shall find \r\n new thing \r\n\r\n heart say candide let recommend \r\n providence \r\n\r\n row league bank place flowery \r\n barren part smooth rugge stream \r\n widen length lose arch frightful rock \r\n reach sky traveller courage commit \r\n current river suddenly contract \r\n place whirl dreadful noise rapidity end \r\n hour see daylight canoe \r\n dash piece rock league creep \r\n rock rock length discover extensive plain \r\n bound inaccessible mountain country cultivate \r\n pleasure necessity side useful \r\n beautiful road cover adorn carriage \r\n glitter form substance man woman \r\n surprising beauty draw large red sheep surpass fleetness \r\n fine courser andalusia tetuan mequinez.[18 \r\n\r\n country say candide well \r\n westphalia \r\n\r\n step cacambo village see \r\n child dress tattered brocade play quoit outskirt \r\n traveller world amuse look \r\n quoit large round piece yellow red green cast \r\n singular lustre traveller pick ground \r\n gold emerald ruby \r\n great ornament mogul throne \r\n\r\n doubt say cacambo child king son \r\n play quoit \r\n\r\n village schoolmaster appear moment call \r\n school \r\n\r\n say candide preceptor royal family \r\n\r\n little truant immediately quit game leave quoit \r\n ground plaything candide gather \r\n run master present humble manner \r\n give understand sign royal highness \r\n forget gold jewel schoolmaster smile fling \r\n ground look candide good deal surprise \r\n go business \r\n\r\n traveller take care gather gold ruby \r\n emerald \r\n\r\n cry candide king child country \r\n bring teach despise gold precious \r\n stone \r\n\r\n cacambo surprised candide length draw near \r\n house village build like european palace \r\n crowd people press door \r\n house hear agreeable music aware delicious \r\n odour cooking cacambo go door hear \r\n talk peruvian mother tongue know \r\n cacambo bear tucuman village language \r\n speak \r\n\r\n interpreter say candide let \r\n public house \r\n\r\n immediately waiter girl dress cloth gold \r\n hair tie ribbon invite sit table \r\n landlord serve dish soup garnish \r\n young parrot boil condor[19 weigh pound \r\n roasted monkey excellent flavour humming bird \r\n dish fly bird exquisite ragout \r\n delicious pastry serve dish kind \r\n rock crystal waiter girl pour liqueur draw \r\n sugar cane \r\n\r\n company chapman waggoner extremely polite \r\n ask cacambo question great circumspection \r\n answer obliging manner \r\n\r\n soon dinner cacambo believe candide \r\n pay reckoning lay large \r\n gold piece pick landlord landlady shout \r\n laughter hold side fit \r\n\r\n gentleman say landlord plain stranger \r\n guest not accustomed pardon laugh \r\n offer pebble highroad payment \r\n reckoning doubtless not money country \r\n not necessary money dine house \r\n hostelry establish convenience commerce ...
#  'cacambo honest fellow \r\n\r\n candide stay time long surinam wait captain \r\n carry remain sheep italy hire \r\n domestic purchase necessary long voyage mynheer \r\n vanderdendur captain large vessel come offer service \r\n\r\n charge say man carry straight \r\n venice servant baggage sheep \r\n\r\n skipper ask piastre candide not hesitate \r\n\r\n oh oh say prudent vanderdendur stranger give \r\n piastre unhesitatingly rich \r\n\r\n return little let know \r\n consideration not undertake voyage \r\n piastre \r\n\r\n shall say candide \r\n\r\n ay say skipper man agree pay \r\n piastre ease \r\n\r\n go declare not carry \r\n venice piastre \r\n\r\n shall reply candide \r\n\r\n oh oh say dutch skipper \r\n piastre trifle man surely sheep laden \r\n immense treasure let let \r\n pay piastre shall \r\n\r\n candide sell small diamond worth \r\n skipper ask freight pay advance \r\n sheep board candide follow little boat join \r\n vessel road skipper seize opportunity set sail \r\n sea wind favour candide dismay stupefy \r\n soon lose sight vessel \r\n\r\n alas say trick worthy old world \r\n\r\n overwhelm sorrow lose sufficient \r\n fortune monarch wait dutch \r\n magistrate distress knock loudly door \r\n enter tell adventure raise voice unnecessary \r\n vehemence mag
avenger voltaire cry \r\n horror society throw member \r\n abyss bartholomew fever tremble \r\n contagion \r\n\r\n p. follow particular monarch prove not \r\n uninteresting achmet iii b. d. dethrone \r\n ivan vi b. d. dethrone charles edward \r\n stuart pretender b. d. auguste iii b. \r\n d. stanislaus b. d. theodore b. d. \r\n observe impossible \r\n king meet \r\n anachronism \r\n\r\n p. françois leopold ragotsky \r\n\r\n                                    \r\n\r\n     + ------------------------------------------------------------+ \r\n     | typographical error correct text                     | \r\n     |                                                             | \r\n     | page xiv chapter xiii head table contents         | \r\n     | amend match chapter head page                | \r\n     | page metaphysicotheo logico cosmolo nigology             | \r\n     | amend metaphysico theologico cosmolo nigology         | \r\n     | page liebnitz amend leibnitz                     | \r\n     | page perserve amend preserve                   | \r\n     | page rougish amend roguish crow amend      | \r\n     | crown                                                     | \r\n     |                                                             | \r\n     | equal number instance word       | \r\n     | hyphenate unhyphenated version            | \r\n     | word retain dung hill dunghill         | \r\n     | new comer newcomer                                   | \r\n     |                                                             | \r\n     | single footnote page move                 | \r\n     | endnote note number indexed        | \r\n     | page reference add moved footnote           | \r\n     | match format endnote                         | \r\n     |                                                             | \r\n     | modern library blurb mail complete list title leave   | \r\n     |                                                      | \r\n     |                                                             | \r\n     | instance massa carara pp     | \r\n     | instance massa carrara page ix        | \r\n     | introduction i.e. distinct book | \r\n     | proper retain                               | \r\n     |                                                             | \r\n     | different spelling cunégonde occur     | \r\n     | introduction robeck occur        | \r\n     | note p. spelt robek text p.       | \r\n     | retain reason                          | \r\n     |                                                             | \r\n     + ------------------------------------------------------------+ \r\n\r\n                                    \r\n\r\n\r\n\r\n\r\n\r\n\r\n        \r\n             end project gutenberg ebook candide \r\n        \r\n\r\n    \r\n\r\n update edition replace previous old edition \r\n rename \r\n\r\n create work print edition not protect u.s. copyright \r\n law mean own united states copyright work \r\n foundation copy distribute united \r\n states permission pay copyright \r\n royalty special rule set forth general term use \r\n license apply copying distribute project \r\n gutenberg ™ electronic work protect project gutenberg ™ \r\n concept trademark project gutenberg register trademark \r\n not charge ebook follow \r\n term trademark license include pay royalty use \r\n project gutenberg trademark not charge \r\n copy ebook comply trademark license \r\n easy use ebook nearly purpose creation ...

# %% [markdown]
# I need to perform a sentinment analysis of the text. To do this I will analyze the sentiment of each chunk of text and then plot a heatmap of the sentiment scores.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
df_sentiment = []

analyzer = SentimentIntensityAnalyzer()

for chunk in chunks_clean:
    vs = analyzer.polarity_scores(chunk)
    df_sentiment.append(vs)

# %% [markdown]
# We have created now done our sentiment analysis

# %%
df_sentiment = pd.DataFrame(df_sentiment,
                            index = range(len(chunks_clean)))

# %% [markdown]
# Instead of having the index be the words in the chunk, I have decided to set the index to the chunk number. If I didn't do this the heatmap is unreadable.

# %%
sns.heatmap(df_sentiment, cmap='Blues', annot=True, cbar=False, linewidths=1);

# %% [markdown]
# Looking at the heatmap, we can visualize the sentiment of the book across chunks from the beginning of the book to the end. From this analysis we can understand how the sentiment changes, when it becomes more negative, or positive. It appears the book ends with a neutral and positive sentiment.
